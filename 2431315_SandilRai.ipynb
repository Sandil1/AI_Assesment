# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
# %cd /content/drive/My Drive/AI_Workshops/Dataset
# Out:
# /content/drive/My Drive/AI_Workshops/Dataset

# %% [markdown]
# **3.1**

# %% [markdown]
# **1.a.1**

# %%
# Loading the csv data
Dataframe = pd.read_csv('Assignment.csv')

# %%
# Displaying the first 10 rows
Dataframe.head(10)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %% [markdown]
# **1.a.2**

# %%
# Displaying the dimension of the dataset
print(f"The dimension of the dataset is (r, c): {Dataframe.shape}.")
# Out:
# The dimension of the dataset is (r, c): (143, 9).

# %% [markdown]
# **1.a.3**

# %%
column_list = Dataframe.columns.tolist()
print(f"The columns of the dataset are: {column_list}.")
# Out:
# The columns of the dataset are: ['Country name', 'score', 'Log GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption', 'Dystopia + residual'].

# %%
# Displaying the datatypes of each column of dataframe
Dataframe.dtypes
# Out:
# Country name                     object
# score                           float64
# Log GDP per capita              float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# Dystopia + residual             float64
# dtype: object

# %% [markdown]
# **1.b.1**

# %% [markdown]
# **3.1**

# %%
mean = Dataframe['score'].mean()
print(f"The mean of column 'score' is {mean}.")
# Out:
# The mean of column 'score' is 5.52758041958042.

# %%
median = Dataframe['score'].median()
print(f"The median of column 'score' is {median}.")
# Out:
# The median of column 'score' is 5.785.

# %%
std = Dataframe['score'].std()
print(f"The standard deviation of column 'score' is {std}.")
# Out:
# The standard deviation of column 'score' is 1.1707165099442995.

# %%
min = Dataframe['score'].min()
print(f"The minimum happiness score of the column 'score' is {min}.")

max = Dataframe['score'].max()
print(f"The maximum happiness score of the column 'score' is {max}.")
# Out:
# The minimum happiness score of the column 'score' is 1.721.
# The maximum happiness score of the column 'score' is 7.741.

# %%
country = Dataframe['Country name'][Dataframe['score'] == max].iloc[0]
print(f"The country with the highest score is {country}.")
# Out:
# The country with the highest score is Finland.

# %%
minCountrydf = Dataframe[Dataframe['score'] == min]
minCountry = minCountrydf['Country name'].iloc[0]
print(f"The country with the lowest score is {minCountry}.")
# Out:
# The country with the lowest score is Afghanistan.

# %% [markdown]
# **1.c.1**

# %%
# Displaying number of missing values in each column of the given dataset
Dataframe.isna().sum()
numericals = Dataframe.select_dtypes(exclude = 'object')

for cols in numericals.columns:
  Dataframe[cols].fillna(Dataframe[cols].median(), inplace = True)

Dataframe.isna().sum()
# Out:
# <ipython-input-372-725ddce75670>:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Dataframe[cols].fillna(Dataframe[cols].median(), inplace = True)
# Country name                    0
# score                           0
# Log GDP per capita              0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# Dystopia + residual             0
# dtype: int64

# %%
Dataframe.describe()
# Out:
#             score  Log GDP per capita  Social support  \
# count  143.000000          143.000000      143.000000
# mean     5.527580            1.379913        1.136493
# std      1.170717            0.420652        0.330111
# min      1.721000            0.000000        0.000000
# 25%      4.726000            1.079000        0.924500
# 50%      5.785000            1.431500        1.237500
# 75%      6.416000            1.733000        1.377000
# max      7.741000            2.141000        1.617000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               143.000000                    143.000000  143.000000
# mean                  0.521486                      0.621049    0.146066
# std                   0.163223                      0.160793    0.072675
# min                   0.000000                      0.000000    0.000000
# 25%                   0.400000                      0.531000    0.092500
# ...

# %%
mean2 = Dataframe['score'].mean()
print(f"The mean of column 'score' is {mean2:.2f}.")
# Out:
# The mean of column 'score' is 5.53.

# %%
med = Dataframe['score'].median()
print(f"The median of column 'score' is {med:.2f}.")
# Out:
# The median of column 'score' is 5.79.

# %%
s = Dataframe['score'].std()
print(f"The standard deviation of column 'score' is {s:.2f}.")
# Out:
# The standard deviation of column 'score' is 1.17.

# %%
selectedCountry = Dataframe['Country name'][Dataframe['score'] > 7.5]
print(f"The countries with a score greater than 7.5 are:")
print(selectedCountry)
# Out:
# The countries with a score greater than 7.5 are:
# 0    Finland
# 1    Denmark
# 2    Iceland
# Name: Country name, dtype: object

# %%
# Returns row unlike above code that selects value from the
# selectedCountryDf = Dataframe.loc[Dataframe['score'] > 7.5]
# print(selectedCountryDf['Country name'])

# %%
sortGDP = Dataframe.sort_values(by='Log GDP per capita', ascending=False)
sortGDP.head(10)
# Out:
#                  Country name  score  Log GDP per capita  Social support  \
# 7                  Luxembourg  7.122               2.141           1.355
# 16                    Ireland  6.838               2.129           1.390
# 29                  Singapore  6.523               2.118           1.361
# 21       United Arab Emirates  6.733               1.983           1.164
# 8                 Switzerland  7.060               1.970           1.425
# 6                      Norway  7.302               1.952           1.517
# 22              United States  6.725               1.939           1.392
# 85  Hong Kong S.A.R. of China  5.316               1.909           1.184
# 1                     Denmark  7.583               1.908           1.520
# 5                 Netherlands  7.319               1.901           1.462
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 7                     0.708                         0.801       0.146
# ...

# %%
Dataframe['Happiness_Category'] = ["Low" if x < 4  else "Medium" if 4 <= x <= 6 else "High" for x in Dataframe['score']]
# print(Dataframe.to_string())

# %% [markdown]
# **Data Visualizations**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(14, 6))
top10 = Dataframe.sort_values(by='score', ascending=False).head(10)
sns.barplot(x='Country name', y='score', data=top10)


plt.title("Top 10 Countries by Happiness Score", fontsize = 16)
plt.xlabel("Country Name", fontsize = 13)
plt.ylabel("Happiness Score", fontsize = 13)
plt.show()

# %%
unhappiestCountry = Dataframe.sort_values(by = 'score', ascending = True).head(10)

plt.figure(figsize=(16, 6))

plt.title("Top 10 Unhappiest Country by Happiness Score", fontsize = 16)
plt.xlabel("Country Name", fontsize = 14)
plt.ylabel("Happiness Score", fontsize = 14)

sns.lineplot(x='Country name', y='score', data=unhappiestCountry)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data = Dataframe['score'], kde = True,bins =35)

plt.title('Distribution of Happiness Scores', fontsize=16)
plt.xlabel('Happiness Score', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %%
sns.set_theme(style = "darkgrid")
sns.scatterplot(data=Dataframe, x='Log GDP per capita', y='score',size = 1)
plt.title('Scatter Plot of Happiness Scores vs. Log GDP per Capita')
plt.xlabel('Log GDP per Capita')
plt.ylabel('Happiness Score')
plt.show()

# %% [markdown]
# **Problem 2**

# %%
# Defining a list of south asian countries
south_asian_countries = ["Afghanistan", "Bangladesh", "Bhutan", "India", "Maldives", "Nepal", "Pakistan", "Srilanka"]
# print(south_asian_countries)

# %%
southAsianDf = Dataframe.loc[Dataframe['Country name'].isin(south_asian_countries)]
print(southAsianDf.to_string())
# Out:
#     Country name  score  Log GDP per capita  Social support  Healthy life expectancy  Freedom to make life choices  Generosity  Perceptions of corruption  Dystopia + residual Happiness_Category
# 92         Nepal  5.158               0.965           0.990                    0.443                         0.653       0.209                      0.115                1.783             Medium
# 107     Pakistan  4.657               1.069           0.600                    0.321                         0.542       0.144                      0.074                1.907             Medium
# 125        India  4.054               1.166           0.653                    0.417                         0.767       0.174                      0.122                0.756             Medium
# 128   Bangladesh  3.886               1.122           0.249                    0.513                         0.775       0.140                      0.167                0.919                Low
# ...

# %%
southAsianDf.to_csv('southAsianDf.csv')

# %% [markdown]
# **Task 2**

# %%
southAsianDf['Composite Score'] = ((southAsianDf['Log GDP per capita'] * 0.4) + (southAsianDf['Social support'] * 0.3) + (southAsianDf['Healthy life expectancy'] * 0.3))
southAsianDf
# Out:
# <ipython-input-389-8a6d13e20cfc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   southAsianDf['Composite Score'] = ((southAsianDf['Log GDP per capita'] * 0.4) + (southAsianDf['Social support'] * 0.3) + (southAsianDf['Healthy life expectancy'] * 0.3))
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# ...

# %%
rank = southAsianDf.sort_values(by = "Composite Score", ascending = False)
display(rank)
display(southAsianDf.sort_values(by='score',ascending=False))
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 125        India  4.054               1.166           0.653
# 107     Pakistan  4.657               1.069           0.600
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 125                    0.417                         0.767       0.174
# 107                    0.321                         0.542       0.144
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
#      Perceptions of corruption  Dystopia + residual Happiness_Category  \
# 92                       0.115                1.783             Medium
# ...

# %%
plt.figure(figsize=(8, 5))
rankSouthAsian = rank.head(5)

sns.barplot(x='Composite Score', y='Country name', data=rankSouthAsian, orient = 'h')
plt.title("Top 5 Countries by Composite Score", fontsize = 16)
plt.show()

# %% [markdown]
# **Task 3**

# %%
southAsianDf
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
#      Perceptions of corruption  Dystopia + residual Happiness_Category  \
# 92                       0.115                1.783             Medium
# ...

# %%
Dataframe['Composite Score'] = ((Dataframe['Log GDP per capita'] * 0.4) + (Dataframe['Social support'] * 0.3) + (Dataframe['Healthy life expectancy'] * 0.3))
Dataframe
# Out:
#          Country name  score  Log GDP per capita  Social support  \
# 0             Finland  7.741               1.844           1.572
# 1             Denmark  7.583               1.908           1.520
# 2             Iceland  7.525               1.881           1.617
# 3              Sweden  7.344               1.878           1.501
# 4              Israel  7.341               1.803           1.513
# ..                ...    ...                 ...             ...
# 138  Congo (Kinshasa)  3.295               0.534           0.665
# 139      Sierra Leone  3.245               0.654           0.566
# 140           Lesotho  3.186               0.771           0.851
# 141           Lebanon  2.707               1.377           0.577
# 142       Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                      0.695                         0.859       0.142
# ...

# %%
# southAsianDf.boxplot(column='score')

# %%
# southAsianScore_minmaxScaling = (southAsianDf['Composite Score'] - southAsianDf['Composite Score'].min()) / (southAsianDf['Composite Score'].max() - southAsianDf['Composite Score'].min())
# print(f"{southAsianScore_minmaxScaling.to_string()}\n")

# southAsianGDP_minmaxScaling = (southAsianDf['Log GDP per capita'] - southAsianDf['Log GDP per capita'].min()) / (southAsianDf['Log GDP per capita'].max() - southAsianDf['Log GDP per capita'].min())
# print(southAsianGDP_minmaxScaling.to_string())

# %%
sns.boxplot(x='score',data=southAsianDf)
plt.title("Boxplot of Score of South Asian Countries")
plt.show()

# %%
sns.boxplot(data = southAsianDf, x = 'Log GDP per capita')
plt.title('Box plot of GDP per capita of South Asian Countries')
# Out:
# Text(0.5, 1.0, 'Box plot of GDP per capita of South Asian Countries')

# %%
firstQuarterCS = southAsianDf['score'].quantile(0.25)
thirdQuarterCS = southAsianDf['score'].quantile(0.75)
IQR = thirdQuarterCS - firstQuarterCS

firstQGDP = southAsianDf['Log GDP per capita'].quantile(0.25)
thirdQGDP = southAsianDf['Log GDP per capita'].quantile(0.75)
IQRGDP = thirdQGDP - firstQGDP

lowerBoundCS = firstQuarterCS - 1.5 * IQR
upperBoundCS = thirdQuarterCS + 1.5 * IQR

lowerBoundGDP = firstQGDP - 1.5 * IQRGDP
upperBoundGDP = thirdQGDP + 1.5 * IQRGDP

# print(firstQuarterCS)
# print(thirdQuarterCS)
# # print(firstQGDP)
# # print(thirdQGDP)
# # print(IQR)
# print(lowerBoundCS)
# print(upperBoundCS)
# # print(lowerBoundGDP)
# # print(upperBoundGDP)
outliers = southAsianDf[(southAsianDf['score'] < lowerBoundCS) | (southAsianDf['score'] > upperBoundCS) & (southAsianDf['Log GDP per capita'] < lowerBoundGDP) | (southAsianDf['Log GDP per capita'] > upperBoundGDP)]
outliers
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 142  Afghanistan  1.721               0.628             0.0
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 142                    0.242                           0.0       0.091
#
#      Perceptions of corruption  Dystopia + residual Happiness_Category  \
# 142                      0.088                0.672                Low
#
#      Composite Score
# 142           0.3238

# %%
firstQuarterCS = southAsianDf['Composite Score'].quantile(0.25)
thirdQuarterCS = southAsianDf['Composite Score'].quantile(0.75)
IQR = thirdQuarterCS - firstQuarterCS

firstQGDP = southAsianDf['Log GDP per capita'].quantile(0.25)
thirdQGDP = southAsianDf['Log GDP per capita'].quantile(0.75)
IQRGDP = thirdQGDP - firstQGDP

lowerBoundCS = firstQuarterCS - 1.5 * IQR
upperBoundCS = thirdQuarterCS + 1.5 * IQR

lowerBoundGDP = firstQGDP - 1.5 * IQRGDP
upperBoundGDP = thirdQGDP + 1.5 * IQRGDP

print(firstQuarterCS)
print(thirdQuarterCS)
print(firstQGDP)
print(thirdQGDP)
print(IQR)
print(lowerBoundCS)
print(upperBoundCS)
print(lowerBoundGDP)
print(upperBoundGDP)
outliers = southAsianDf[(southAsianDf['Composite Score'] < lowerBoundCS) | (southAsianDf['Composite Score'] > upperBoundCS) & (southAsianDf['Log GDP per capita'] < lowerBoundGDP) | (southAsianDf['Log GDP per capita'] > upperBoundGDP)]
outliers
# Out:
# 0.6774000000000001
# 0.7874
# 0.965
# 1.122
# 0.10999999999999988
# 0.5124000000000003
# 0.9523999999999998
# 0.7294999999999998
# 1.3575000000000004
#     Country name  score  Log GDP per capita  Social support  \
# 142  Afghanistan  1.721               0.628             0.0
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 142                    0.242                           0.0       0.091
#
#      Perceptions of corruption  Dystopia + residual Happiness_Category  \
# 142                      0.088                0.672                Low
#
#      Composite Score
# 142           0.3238

# %%
sns.scatterplot(data = southAsianDf,x = 'Log GDP per capita', y = 'score',label='Normal countries')
sns.scatterplot(data = outliers,x = 'Log GDP per capita', y = 'score',color='red',label='Outlier')


plt.title('Scatter Plot of Happiness Score vs. Log GDP per Capita')
plt.xlabel('Log GDP per Capita')
plt.ylabel('Happiness Score')
plt.show()

# %%
# southAsianDf['Outliers'] = southAsianDf

# %%
# sAsianWide = ["Outlier" if ((southAsianDf['Composite Score'] < lowerBoundCS) | (southAsianDf['Composite Score'] > upperBoundCS) & (southAsianDf['Log GDP per capita'] < lowerBoundGDP) | (southAsianDf['Log GDP per capita'] > upperBoundGDP))  else "Normal" for x in Dataframe['Log GDP per capita', 'Composite Score']]

# %%
correlation = southAsianDf['Freedom to make life choices'].corr(southAsianDf['score'], method = 'pearson')
print(f"The correlation between metrics 'Freedom to make life choices' and 'score' is {correlation:.2f}")

correlationGS = southAsianDf['Generosity'].corr(southAsianDf['score'], method = 'pearson')
print(f"The correlation between metrics 'Generosity' and 'score' is {correlationGS:.2f}")
# Out:
# The correlation between metrics 'Freedom to make life choices' and 'score' is 0.80
# The correlation between metrics 'Generosity' and 'score' is 0.88

# %%
plt.figure(figsize = (10,6))
sns.regplot(x = 'Freedom to make life choices', y = 'score', data = southAsianDf)
plt.title("Scatter Plot of 'Freedom to make life choices' vs. 'score'")
plt.xlabel('Freedom to make life choices')
plt.ylabel('score')
plt.show()

# %%
plt.figure(figsize = (12,6))
sns.regplot(x = 'Generosity', y = 'score', data = southAsianDf)
plt.title("Scatter Plot of 'Generosity' vs. 'score'")
plt.xlabel('Generosity')
plt.ylabel('score')
plt.show()

# %%
southAsianDf['GDP-Score Gap'] = southAsianDf['Log GDP per capita'] - southAsianDf['score']
southAsianDf
# Out:
# <ipython-input-406-3664e529752a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   southAsianDf['GDP-Score Gap'] = southAsianDf['Log GDP per capita'] - southAsianDf['score']
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# ...

# %%
rankSA = southAsianDf.sort_values(by = 'GDP-Score Gap', ascending = False)
rankSAscending = southAsianDf.sort_values(by='GDP-Score Gap', ascending = True)

print(f"The ranking of south asian countries based on the GDP-Score Gap is: {rankSA.to_string()}\n")
print(f"The ranking of south asian countries based on the GDP-Score Gap in ascending order is: {rankSAscending.to_string()}\n")
# Out:
# The ranking of south asian countries based on the GDP-Score Gap is:     Country name  score  Log GDP per capita  Social support  Healthy life expectancy  Freedom to make life choices  Generosity  Perceptions of corruption  Dystopia + residual Happiness_Category  Composite Score  GDP-Score Gap
# 142  Afghanistan  1.721               0.628           0.000                    0.242                         0.000       0.091                      0.088                0.672                Low           0.3238         -1.093
# 128   Bangladesh  3.886               1.122           0.249                    0.513                         0.775       0.140                      0.167                0.919                Low           0.6774         -2.764
# 125        India  4.054               1.166           0.653                    0.417                         0.767       0.174                      0.122                0.756             Medium           0.7874         -2.888
# ...

# %%
plt.figure(figsize=(10, 6))

sns.barplot(x='GDP-Score Gap', y='Country name', data=rankSA, orient = 'h', label = 'Top 3 countries with least GDP Gap')
sns.barplot(x='GDP-Score Gap', y='Country name', data=rankSA.tail(2), orient = 'h',color='red', label = 'Countries with higher Negative Gap')
plt.title("Top 5 Countries by GDP Gap", fontsize = 16)

# plt.xlabel("South Asian Country")
# plt.ylabel("Happiness Score")
plt.show()

# %% [markdown]
# **3.3**

# %%
middleEast = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan",
"Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria",
"United Arab Emirates", "Yemen"]

# %%
middleEastDf = Dataframe.loc[Dataframe['Country name'].isin(middleEast)]
middleEastDf.describe()
# Out:
#            score  Log GDP per capita  Social support  Healthy life expectancy  \
# count  10.000000           10.000000       10.000000                10.000000
# mean    5.412100            1.489850        1.161250                 0.553650
# std     1.566201            0.393134        0.263726                 0.116019
# min     2.707000            0.671000        0.577000                 0.293000
# 25%     4.370250            1.290750        1.031000                 0.520625
# 50%     5.562500            1.433250        1.200750                 0.559500
# 75%     6.698250            1.832250        1.341000                 0.588250
# max     7.341000            1.983000        1.513000                 0.740000
#
#        Freedom to make life choices  Generosity  Perceptions of corruption  \
# count                      10.00000   10.000000                  10.000000
# mean                        0.56300    0.139550                   0.143350
# ...

# %%
# 5.412100 > 3.895200
southAsianDf.describe()
# Out:
#           score  Log GDP per capita  Social support  Healthy life expectancy  \
# count  5.000000            5.000000        5.000000                 5.000000
# mean   3.895200            0.990000        0.498400                 0.387200
# std    1.316003            0.215818        0.382916                 0.106411
# min    1.721000            0.628000        0.000000                 0.242000
# 25%    3.886000            0.965000        0.249000                 0.321000
# 50%    4.054000            1.069000        0.600000                 0.417000
# 75%    4.657000            1.122000        0.653000                 0.443000
# max    5.158000            1.166000        0.990000                 0.513000
#
#        Freedom to make life choices  Generosity  Perceptions of corruption  \
# count                      5.000000    5.000000                   5.000000
# mean                       0.547400    0.151600                   0.113200
# ...

# %%
middleEastDf_sorted = middleEastDf.sort_values('score',ascending=False)
middleEastDf_sorted
# Out:
#              Country name  score  Log GDP per capita  Social support  \
# 4                  Israel  7.341              1.8030          1.5130
# 12                 Kuwait  6.951              1.8450          1.3640
# 21   United Arab Emirates  6.733              1.9830          1.1640
# 27           Saudi Arabia  6.594              1.8420          1.3610
# 61                Bahrain  5.959              1.4315          1.2375
# 91                   Iraq  5.166              1.2490          0.9960
# 99                   Iran  4.923              1.4350          1.1360
# 124                Jordan  4.186              1.2620          0.9830
# 132                 Yemen  3.561              0.6710          1.2810
# 141               Lebanon  2.707              1.3770          0.5770
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                     0.7400                         0.641      0.1530
# ...

# %%
middleEastDf['Composite Score'] = ((middleEastDf['Log GDP per capita'] * 0.4) + (middleEastDf['Social support'] * 0.3) + (middleEastDf['Healthy life expectancy'] * 0.3))
middleEastDf

middleEastDf_sorted = middleEastDf.sort_values('score',ascending=False)
middleEastDf_sorted['Region'] = 'Middle East'
southAsianDf['Region'] = 'South Asia'


display(middleEastDf_sorted.head(3))
display(middleEastDf_sorted.tail(3).iloc[::-1].reset_index(drop=True))

display(southAsianDf.head(3))
display(southAsianDf.tail(3).iloc[::-1].reset_index(drop=True))


plt.figure(figsize=(10,5))
plt.title("Countries with the highest and the lowest happiness score in each region")
plt.xticks(rotation=45)


sns.barplot(data=pd.concat([middleEastDf_sorted.head(3),southAsianDf.head(3),middleEastDf_sorted.tail(3),southAsianDf.tail(3)]), x='Country name',y='score',hue='Region',palette='coolwarm')
# Out:
# <ipython-input-413-afe887060020>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   middleEastDf['Composite Score'] = ((middleEastDf['Log GDP per capita'] * 0.4) + (middleEastDf['Social support'] * 0.3) + (middleEastDf['Healthy life expectancy'] * 0.3))
# <ipython-input-413-afe887060020>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   southAsianDf['Region'] = 'South Asia'
#             Country name  score  Log GDP per capita  Social support  \
# ...

# %%
stdM = middleEastDf['score'].std()
print(f"The standard deviation of 'score' of middle eastern countries is {stdM:.2f}")

stdS = southAsianDf['score'].std()
print(f"The standard deviation of 'score' of south asian countries is {stdS:.2f}")
# Out:
# The standard deviation of 'score' of middle eastern countries is 1.57
# The standard deviation of 'score' of south asian countries is 1.32

# %%
middleEastDf
# Out:
#              Country name  score  Log GDP per capita  Social support  \
# 4                  Israel  7.341              1.8030          1.5130
# 12                 Kuwait  6.951              1.8450          1.3640
# 21   United Arab Emirates  6.733              1.9830          1.1640
# 27           Saudi Arabia  6.594              1.8420          1.3610
# 61                Bahrain  5.959              1.4315          1.2375
# 91                   Iraq  5.166              1.2490          0.9960
# 99                   Iran  4.923              1.4350          1.1360
# 124                Jordan  4.186              1.2620          0.9830
# 132                 Yemen  3.561              0.6710          1.2810
# 141               Lebanon  2.707              1.3770          0.5770
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                     0.7400                         0.641      0.1530
# ...

# %%
combined_df = pd.concat([middleEastDf_sorted,southAsianDf])
values = combined_df.groupby('Region')[['Log GDP per capita','Social support','Healthy life expectancy']].mean()
values.plot(kind='bar',figsize=(10,6))
plt.title("Average score of factors affecting Happiness of Middle East and South Asia")
plt.xlabel("Region")
plt.ylabel("Average score")
plt.xticks(rotation=0)
# Out:
# (array([0, 1]), [Text(0, 0, 'Middle East'), Text(1, 0, 'South Asia')])

# %%
middleEastDf.describe()
# Out:
#            score  Log GDP per capita  Social support  Healthy life expectancy  \
# count  10.000000           10.000000       10.000000                10.000000
# mean    5.412100            1.489850        1.161250                 0.553650
# std     1.566201            0.393134        0.263726                 0.116019
# min     2.707000            0.671000        0.577000                 0.293000
# 25%     4.370250            1.290750        1.031000                 0.520625
# 50%     5.562500            1.433250        1.200750                 0.559500
# 75%     6.698250            1.832250        1.341000                 0.588250
# max     7.341000            1.983000        1.513000                 0.740000
#
#        Freedom to make life choices  Generosity  Perceptions of corruption  \
# count                      10.00000   10.000000                  10.000000
# mean                        0.56300    0.139550                   0.143350
# ...

# %%
southAsianDf.describe()
# Out:
#           score  Log GDP per capita  Social support  Healthy life expectancy  \
# count  5.000000            5.000000        5.000000                 5.000000
# mean   3.895200            0.990000        0.498400                 0.387200
# std    1.316003            0.215818        0.382916                 0.106411
# min    1.721000            0.628000        0.000000                 0.242000
# 25%    3.886000            0.965000        0.249000                 0.321000
# 50%    4.054000            1.069000        0.600000                 0.417000
# 75%    4.657000            1.122000        0.653000                 0.443000
# max    5.158000            1.166000        0.990000                 0.513000
#
#        Freedom to make life choices  Generosity  Perceptions of corruption  \
# count                      5.000000    5.000000                   5.000000
# mean                       0.547400    0.151600                   0.113200
# ...

# %%
rangeME = middleEastDf['score'].max() - middleEastDf['score'].min()
print(f"The range of 'score' of middle eastern countries is {rangeME:.2f}")

rangeSE = southAsianDf['score'].max() - southAsianDf['score'].min()
print(f"The range of 'score' of south asian countries is {rangeSE:.2f}")
# Out:
# The range of 'score' of middle eastern countries is 4.63
# The range of 'score' of south asian countries is 3.44

# %%
coeffVariationME = 100 *stdM / middleEastDf['score'].mean()
print(f"The coefficient of variation of 'score' of middle eastern countries is {coeffVariationME:.2f}%")

coeffVariationSA = 100 * stdS / southAsianDf['score'].mean()
print(f"The coefficient of variation of 'score' of south asian countries is {coeffVariationSA:.2f}%")
# Out:
# The coefficient of variation of 'score' of middle eastern countries is 28.94%
# The coefficient of variation of 'score' of south asian countries is 33.79%

# %%
corelSAFreedom = southAsianDf['Freedom to make life choices'].corr(southAsianDf['score'], method = 'pearson')
print(f"The correlation between metrics 'Freedom to make life choices' and 'score' of south asian countries is {corelSAFreedom:.2f}")

corelSAGenerosity = southAsianDf['Generosity'].corr(southAsianDf['score'], method = 'pearson')
print(f"The correlation between metrics 'Generosity' and 'score' of south asian countries is {corelSAGenerosity:.2f}")

corelMEFreedom = middleEastDf['Freedom to make life choices'].corr(middleEastDf['score'], method = 'pearson')
print(f"The correlation between metrics 'Freedom to make life choices' and 'score' of middle eastern countries is {corelMEFreedom:.2f}")

corelMEGenerosity = middleEastDf['Generosity'].corr(middleEastDf['score'], method = 'pearson')
print(f"The correlation between metrics 'Generosity' and 'score' of middle eastern countries is {corelMEGenerosity:.2f}")
# Out:
# The correlation between metrics 'Freedom to make life choices' and 'score' of south asian countries is 0.80
# The correlation between metrics 'Generosity' and 'score' of south asian countries is 0.88
# The correlation between metrics 'Freedom to make life choices' and 'score' of middle eastern countries is 0.87
# The correlation between metrics 'Generosity' and 'score' of middle eastern countries is 0.62

# %%
plt.figure(figsize = (8,5))
sns.scatterplot(data=southAsianDf, x='Freedom to make life choices', y='score')
plt.title('Scatter Plot of Freedom to make life choices vs. Happiness score in South Asian countries')
plt.xlabel('Freedom to make life choices')
plt.ylabel('Happiness Score')
plt.show()

# %%
plt.figure(figsize = (8,5))
sns.scatterplot(data=southAsianDf, x='Generosity', y='score',size = 1)
plt.title('Scatter Plot of Happiness Scores vs. Generosity in South Asian countries')
plt.xlabel('Generosity')
plt.ylabel('Happiness Score')
plt.show()

# %%
plt.figure(figsize = (10,6))
sns.scatterplot(data=southAsianDf, x='score', y='Generosity',size = 1)
plt.title('Scatter Plot of Happiness Scores vs. Generosity in South Asian countries')
plt.xlabel('Happiness Score')
plt.ylabel('Generosity')
plt.show()
display(southAsianDf)
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
#      Perceptions of corruption  Dystopia + residual Happiness_Category  \
# 92                       0.115                1.783             Medium
# ...

# %%
plt.figure(figsize = (10,6))
sns.scatterplot(data=middleEastDf, x='score', y='Freedom to make life choices',size = 1)
plt.title('Scatter Plot of Happiness Scores vs. Freedom to make life choices in Middle eastern countries')
plt.xlabel('Freedom to make life choices')
plt.ylabel('Happiness Score')
plt.show()

# %%
plt.figure(figsize = (10,6))
sns.scatterplot(data=middleEastDf, x='score', y='Generosity',size = 1)
plt.title('Scatter Plot of Happiness Scores vs. Generosity in Middle Eastern countries')
plt.xlabel('Happiness Score')
plt.ylabel('Generosity')
plt.show()

# %%
sns.boxplot(data=middleEastDf,x='score')
plt.title("Box plot of score of the Middle Eastern region ")
# Out:
# Text(0.5, 1.0, 'Box plot of score of the Middle Eastern region ')

# %%
sns.boxplot(data=middleEastDf,x='Log GDP per capita')
plt.title("Box plot of GDP per capita of the Middle Eastern region ")
# Out:
# Text(0.5, 1.0, 'Box plot of GDP per capita of the Middle Eastern region ')

# %%
sns.boxplot(data=southAsianDf,x='Log GDP per capita')
plt.title("Box plot of GDP per capita of the South Asian region ")
# Out:
# Text(0.5, 1.0, 'Box plot of GDP per capita of the South Asian region ')

# %%
sns.boxplot(data=southAsianDf,x='score')
plt.title("Box plot of score of the South Asian region ")
# Out:
# Text(0.5, 1.0, 'Box plot of score of the South Asian region ')

# %%
numericalSA = southAsianDf.select_dtypes(include=['number'])
plt.figure(figsize=(6, 6))
plt.title("Heat map of different metrics of the South Asian Region")
sns.heatmap(numericalSA.corr(), annot=True, cmap='coolwarm', fmt = '.1f')

# southAsianDf.dtypes
# Out:
# <Axes: title={'center': 'Heat map of different metrics of the South Asian Region'}>

# %%
numericalME = middleEastDf.select_dtypes(include=['number'])
plt.figure(figsize=(6, 6))
plt.title("Heat map of different metrics of Middle East")
sns.heatmap(numericalME.corr(), annot=True, cmap='coolwarm', fmt = '.1f')
# Out:
# <Axes: title={'center': 'Heat map of different metrics of Middle East'}>

# %%
df = southAsianDf[southAsianDf['Country name'] != 'Afghanistan']
display(df)
df.describe()
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 128   Bangladesh  3.886               1.122           0.249
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 128                    0.513                         0.775       0.140
#
#      Perceptions of corruption  Dystopia + residual Happiness_Category  \
# 92                       0.115                1.783             Medium
# 107                      0.074                1.907             Medium
# 125                      0.122                0.756             Medium
# ...

# %%
southAsianDf.describe()
# Out:
#           score  Log GDP per capita  Social support  Healthy life expectancy  \
# count  5.000000            5.000000        5.000000                 5.000000
# mean   3.895200            0.990000        0.498400                 0.387200
# std    1.316003            0.215818        0.382916                 0.106411
# min    1.721000            0.628000        0.000000                 0.242000
# 25%    3.886000            0.965000        0.249000                 0.321000
# 50%    4.054000            1.069000        0.600000                 0.417000
# 75%    4.657000            1.122000        0.653000                 0.443000
# max    5.158000            1.166000        0.990000                 0.513000
#
#        Freedom to make life choices  Generosity  Perceptions of corruption  \
# count                      5.000000    5.000000                   5.000000
# mean                       0.547400    0.151600                   0.113200
# ...

# %%
sns.histplot(data = southAsianDf['score'], kde = True,bins =5)
plt.title("Distribution of Happiness Scores of South Asian Countries")
plt.xlabel("Happiness Score")
# Out:
# Text(0.5, 0, 'Happiness Score')

# %%
sns.histplot(data = df['score'], kde = True,bins =5)
# Out:
# <Axes: xlabel='score', ylabel='Count'>
